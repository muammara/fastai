# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import os

# %%
from fastai.vision import *
from fastai.metrics import error_rate
from fastai import *
from pathlib import WindowsPath

# %%
os.chdir('../../mywork/imageclassification/images/')

# %%
#bs = 64
bs = 16  # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %%
path=WindowsPath('./')
path
# Out:
# WindowsPath('.')

# %%
np.random.seed(2)
data = ImageDataBunch.from_folder(path,ds_tfms=get_transforms(), size=100, bs=bs, valid_pct=.2,
                                  ).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Apple Braeburn', 'Apple Crimson Snow', 'Apple Golden 1', 'Apple Golden 2', 'Apple Golden 3', 'Apple Granny Smith', 'Apple Pink Lady', 'Apple Red 1', 'Apple Red 2', 'Apple Red 3', 'Apple Red Delicious', 'Apple Red Yellow 1', 'Apple Red Yellow 2', 'Apricot', 'Avocado', 'Avocado ripe', 'Banana', 'Banana Lady Finger', 'Banana Red', 'Beetroot', 'Blueberry', 'Cactus fruit', 'Cantaloupe 1', 'Cantaloupe 2', 'Carambula', 'Cauliflower', 'Cherry 1', 'Cherry 2', 'Cherry Rainier', 'Cherry Wax Black', 'Cherry Wax Red', 'Cherry Wax Yellow', 'Chestnut', 'Clementine', 'Cocos', 'Dates', 'Eggplant', 'Ginger Root', 'Granadilla', 'Grape Blue', 'Grape Pink', 'Grape White', 'Grape White 2', 'Grape White 3', 'Grape White 4', 'Grapefruit Pink', 'Grapefruit White', 'Guava', 'Hazelnut', 'Huckleberry', 'Kaki', 'Kiwi', 'Kohlrabi', 'Kumquats', 'Lemon', 'Lemon Meyer', 'Limes', 'Lychee', 'Mandarine', 'Mango', 'Mango Red', 'Mangostan', 'Maracuja', 'Melon Piel de Sapo', 'Mulberry', 'Nectarine', 'Nectarine Flat', 'N
# ...

# %%
learn = cnn_learner(data, models.resnet18, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to C:\Users\muamma/.torch\models\resnet18-5c106cde.pth
# 100%|█████████████████████████████████████████████████████████████████| 46827520/46827520 [00:10<00:00, 4375320.98it/s]

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.244227</td>
#       <td>0.058152</td>
#       <td>0.018713</td>
#       <td>09:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.114531</td>
#       <td>0.011754</td>
#       <td>0.004186</td>
#       <td>09:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.038324</td>
#       <td>0.004293</td>
#       <td>0.001416</td>
#       <td>08:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.044092</td>
#       <td>0.003103</td>
#       <td>0.001046</td>
#       <td>08:55</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-ResNet18-1')

# %%
print(len(data.classes));print(data.classes)
# Out:
# 121
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Apple Red 2', 'Apple Braeburn', 8),
#  ('Lemon', 'Grapefruit White', 4),
#  ('Mango Red', 'Pear Forelle', 3)]

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.014086</td>
#       <td>0.000876</td>
#       <td>0.000308</td>
#       <td>12:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-ResNet18-1');

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...
